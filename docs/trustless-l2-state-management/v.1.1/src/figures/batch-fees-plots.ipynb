# %%
# Batch fee mult diffBatches > 0 (mult)
import numpy as np 
from matplotlib import pyplot as plt 
plt.style.use('seaborn')

fig, ax = plt.subplots(figsize=(6, 6))


# multiplierBatchFee = 1000
x = np.arange(0,13)
y = []
i = 0
while (i < len(x)):
    y.append(((1000.0**x[i])/(1000.0**x[i])-1)*100) 
    i += 1  
ax.plot(x,y, label = "multiplierBatchFee = 1000")

# multiplierBatchFee = 1000
x = np.arange(0,13)
y = []
i = 0
while (i < len(x)):
    y.append(((1012.0**x[i])/(1000.0**x[i])-1)*100) 
    i += 1  
ax.plot(x,y, label = "multiplierBatchFee = 1012")    
    
# multiplierBatchFee = 1000
x = np.arange(0,13)
y = []
i = 0
while (i < len(x)):
    y.append(((1024.0**x[i])/(1000.0**x[i])-1)*100) 
    i += 1  
ax.plot(x,y, label = "multiplierBatchFee = 1024")    
 
ax.set_xlabel("diffBatches")
ax.set_ylabel("batch fee variation %")
ax.set_xticks(range(len(x)))
ax.set_xmargin(0)
ax.legend()
plt.savefig('mult.png')
plt.show()

# %%
# Batch fee mult diffBatches > 0 (mult)
import numpy as np 
from matplotlib import pyplot as plt 
plt.style.use('seaborn')

fig, ax = plt.subplots(figsize=(6, 6))


# multiplierBatchFee = 1000
x = np.arange(0,13)
y = []
i = 0
while (i < len(x)):
    y.append(((1000.0**x[i])/(1000.0**x[i])-1)*100) 
    i += 1  
ax.plot(x,y, label = "multiplierBatchFee = 1000")

# multiplierBatchFee = 1012
x = np.arange(0,13)
y = []
i = 0
while (i < len(x)):
    y.append(((1000.0**x[i])/(1012.0**x[i])-1)*100) 
    i += 1  
ax.plot(x,y, label = "multiplierBatchFee = 1012")    
    
# multiplierBatchFee = 1024
x = np.arange(0,13)
y = []
i = 0
while (i < len(x)):
    y.append(((1000.0**x[i])/(1024.0**x[i])-1)*100) 
    i += 1  
ax.plot(x,y, label = "multiplierBatchFee = 1024")    
 
ax.set_xlabel("diffBatches")
ax.set_ylabel("batch fee variation %")
ax.set_xticks(range(len(x)))
ax.set_xmargin(0)
ax.legend()
plt.savefig('div.png')
plt.show()
